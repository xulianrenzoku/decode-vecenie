# %%
import os
import re
import pandas as pd
import numpy as np
from tika import parser

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_rows', 100)

# %%
os.listdir('../processed_pdf')
# Out:
# ['2020.pdf', '2021.pdf', '2023.pdf', '2022.pdf']

# %% [markdown]
# ## Read Raw Data

# %%
raw = parser.from_file('../processed_pdf/2022.pdf')
# print(raw['content'])

# %%
raw = raw['content'].split('\n')

# %%
print(len(raw))
raw = [row for row in raw if row != '']
print(len(raw))
# Out:
# 6983
# 5060

# %% [markdown]
# ## Get Tier

# %%
def get_tier(raw):
    tier_dict = {}
    tier_flag = 0
    
    for i, row in enumerate(raw, 0):
        if row.startswith('Tier'):
            key, value = row.split(': ')
            tier_dict[key] = value
            tier_flag = 1
        else:
            if tier_flag == 1 and row != '2022NBA DRAFT GUIDE':
                return tier_dict, raw[i:]

# %%
tier_dict, raw = get_tier(raw)

# %%
tier_dict
# Out:
# {'Tier 2': 'All-Star Upside',
#  'Tier 3': 'High-Leverage Starters',
#  'Tier 4': 'Starters and Difference-Makers',
#  'Tier 5': 'Late First-Round, Guaranteed Contract Guys',
#  'Tier 6': 'Two-Way Contracts'}

# %% [markdown]
# ## Get Big Board

# %%
def get_raw_big_board(raw):
    raw_bb_dict = {}
    bb_flag = 0
    bb_data = []
    
    for i, row in enumerate(raw, 0):
        if row.startswith('RANK'):
            raw_bb_dict['columns'] = row
            bb_flag = 1
        else:
            if bb_flag == 1:
                if row.split(' ')[0] != '100':
                    bb_data.append(row)
                else:
                    bb_data.append(row)
                    raw_bb_dict['data'] = bb_data
                    return raw_bb_dict, raw[i+1:]

# %%
raw_bb_dict, raw = get_raw_big_board(raw)

# %%
# Minor Edit
raw_bb_dict['data'][-2] = '99 Justin Bean, Utah State F 25 6-7 N/A 7'
raw_bb_dict['data'][-1] = '100 Tyson Etienne, Wichita State G 22 6-2 N/A 7'

# %%
def build_big_board(raw_bb_dict):
    columns = [col.replace('.', '').replace(',', '')
               for col in raw_bb_dict['columns'].split(' ')]
    
    data = [row for row in raw_bb_dict['data']
            if len(row.split(' ')[0]) <= 3]
    
    processed_data = []
    for row in data:
        front, back = row.split(', ')
        row_adj = [front.split(' ')[0]] + [' '.join(front.split(' ')[1:])] + \
                  [' '.join(back.split(' ')[:-5])] + back.split(' ')[-5:]
        processed_data.append(row_adj)
    
    return pd.DataFrame(processed_data, columns=columns)

# %%
big_board = build_big_board(raw_bb_dict)
big_board
# Out:
#    RANK               PLAYER           SCHOOL/TEAM  POS AGE    HT  WING TIER
# 0    01        Chet Holmgren               Gonzaga    C  20   7-0   7-6    2
# 1    02     Jabari Smith Jr.                Auburn    F  19  6-10   7-1    2
# 2    03       Paolo Banchero                  Duke    F  19  6-10   7-1    2
# 3    04           Jaden Ivey                Purdue    G  20   6-4   N/A    2
# 4    05   Bennedict Mathurin               Arizona    W  20   6-6   6-9    3
# 5    06        Jeremy Sochan                Baylor  W/F  19   6-9   7-0    3
# 6    07        Dyson Daniels       G League Ignite    G  19   6-7  6-11    3
# 91   92        Buddy Boeheim              Syracuse    W  22   6-6   6-7    7
# 92   93          Brady Manek        North Carolina    F  23   6-9   7-1    7
# 93   94   Jeenathan Williams               Buffalo    W  23   6-6   7-0    7
# 94   95           Mike DeVoe          Georgia Tech    W  22   6-5   6-7    7
# 95   96     Lucas Williamson        Loyola Chicago    G  23   6-4   N/A    7
# 96   97     Jermaine Samuels             Villanova    F  23   6-7  6-11    7
# 97   98   Kenneth Lofton Jr.        Louisiana Tech    F  19   6-7  6-11    7
# 98   99          Justin Bean            Utah State    F  25   6-7   N/A    7
# 99  100        Tyson Etienne         Wichita State    G  22   6-2   N/A    7

# %%
big_board['PLAYER'] = big_board['PLAYER'].apply(lambda x: 'Dominick Barlow' if x == 'Dom Barlow' else x)

# %% [markdown]
# ## Get Scouting Report

# %% [markdown]
# ### Build Raw Dict

# %%
raw = [row.replace('\t', ' ') for row in raw]

# %%
def identify_scouting_report(raw, big_board):
    sr_dict = {}
    idx_breaks = []
    players_identified = []

    for player in big_board.PLAYER.values:
        for i, row in enumerate(raw, 0):
            if row.endswith(player):
                idx_breaks.append(i)
                players_identified.append(player)
                break
    
    idx_breaks = idx_breaks + [len(raw)]

    for i, player in enumerate(players_identified, 0):
        start = idx_breaks[i]
        end = idx_breaks[i+1]
        sr_dict[player] = [row.lstrip(' ') for row in raw[start:end]]
        
    # report
    print(f'# of players identified: {len(players_identified)}')
    
    return sr_dict

# %%
sr_dict = identify_scouting_report(raw, big_board)
# Out:
# # of players identified: 75

# %%
def check_categories(sc):
    n_err = 0
    for cat in ['STRENGTHS', 'WEAKNESSES', 'SUMMARY']:
        if cat not in sc:
            print(cat)
            n_err += 1
    return n_err

# %%
for player in sr_dict.keys():
    if check_categories(sr_dict[player]) >= 1:
        print(player)

# %% [markdown]
# ### Clean Scouting Report

# %%
def clean_scouting_report(sr):
    school = sr[1].split(' | ')[1]
    idx_breaks = []
    
    cats = ['STRENGTHS', 'WEAKNESSES', 'SUMMARY']
    
    for cat in cats:
        for i, row in enumerate(sr, 0):
            if row == cat:
                idx_breaks.append(i)
                break
                
    idx_breaks = idx_breaks + [len(sr)]
    
    output_dict = {}
    
    for i, cat in enumerate(cats, 0):
        start = idx_breaks[i]
        end = idx_breaks[i+1]
        content = [row.strip('-') for row in sr[start:end] 
                   if row.endswith(' ') or row.endswith('.') or row.endswith('-')]
        content = [row for row in content
                   if re.search(f'^20..-.. {school}', row) is None 
                   and re.search('^20..-..', row) is None
                   and row.strip(' ') != 'NCAA']
        output_dict[cat] = ''.join(content)

    return output_dict

# %%
clean_scouting_report(sr_dict['Jeremy Sochan'])
# Out:
#  'SUMMARY': 'As you can see, Sochan’s strengths list is much longer than the weaknesses list. I’m very high on Sochan’s game and would be willing to bet on him pretty high on draft night. If Sochan shoots, the ceiling is through the roof. Due to his disruptiveness, size and quickness, he has a real chance to be an All-Defense-caliber guy. He can handle and be versatile on offense, and it feels like he’s just scratching the surface of what his long-term potential is on that end. The NBA covets guys who are 6-foot-9 with this kind of defensive upside, and the 2022 playoffs showed how important versatile defenders are in today’s league. If you buy into Sochan’s potential to shoot at all, there are some potential star outcomes here that could make him a worthwhile investment.'}

# %%
for key in sr_dict:
    sr_dict[key] = clean_scouting_report(sr_dict[key])

# %% [markdown]
# ## Assemble Data

# %%
big_board['is_sr'] = big_board['PLAYER'].apply(lambda x: 1 if x in sr_dict.keys() else 0)
big_board = big_board[big_board['is_sr'] == 1]
big_board.shape
# Out:
# (75, 9)

# %% [markdown]
# ### Add Scouting Report

# %%
cats = ['STRENGTHS', 'WEAKNESSES', 'SUMMARY']
for cat in cats:
    big_board[cat] = big_board['PLAYER'].apply(lambda x: sr_dict[x][cat])
    
big_board = big_board.drop('is_sr', axis=1)

# %% [markdown]
# ### Add Tier Description

# %%
big_board['TIER_DESCRIP'] = big_board['TIER'].apply(lambda x: tier_dict[f'Tier {x}'])

# %%
big_board.head()
# Out:
#   RANK              PLAYER SCHOOL/TEAM POS AGE    HT WING TIER  \
# 0   01       Chet Holmgren     Gonzaga   C  20   7-0  7-6    2
# 1   02    Jabari Smith Jr.      Auburn   F  19  6-10  7-1    2
# 2   03      Paolo Banchero        Duke   F  19  6-10  7-1    2
# 3   04          Jaden Ivey      Purdue   G  20   6-4  N/A    2
# 4   05  Bennedict Mathurin     Arizona   W  20   6-6  6-9    3
#
#                                            STRENGTHS  \
# 0  The consensus top recruit in the 2021 recruiti...
# 1  Elite consensus five-star, and a top-10 recrui...
# 2  A clear five-star, top-five recruit in the cou...
# 3  Was a consensus four-star recruit who was a to...
# 4  Originally from Montreal and played basketball...
#
#                                           WEAKNESSES  \
# 0  End of the day, it basically comes down to one...
# 1  While Smith is extremely functional athletical...
# 2  More of a fluid athlete than an explosive one....
# 3  I don’t think I’d call Ivey a negative in term...
# 4  A lot of rawness in his game on both ends. The...
#
#                                              SUMMARY            TIER_DESCRIP
# 0  The word “unique” is overused in scouting circ...         All-Star Upside
# 1  Much like the other two prospects in the class...         All-Star Upside
# 2  Where you are on Banchero depends entirely on ...         All-Star Upside
# 3  Ivey is all about how much you value athletic ...         All-Star Upside
# 4  There is a high floor for Mathurin because of ...  High-Leverage Starters

# %% [markdown]
# ## Save output

# %%
big_board.to_csv('../processed_csv/2022.csv', index=False)
