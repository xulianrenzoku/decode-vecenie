# %%
import os
import re
import pandas as pd
import numpy as np
from tika import parser

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_rows', 100)

# %%
os.listdir('../processed_pdf')
# Out:
# ['2020.pdf', '2021.pdf', '2023.pdf', '2022.pdf']

# %% [markdown]
# ## Read Raw Data

# %%
raw = parser.from_file('../processed_pdf/2020.pdf')
# print(raw['content'])

# %%
raw = raw['content'].split('\n')

# %%
print(len(raw))
raw = [row for row in raw if row != '']
print(len(raw))
# Out:
# 5646
# 4200

# %% [markdown]
# ## Get Tier

# %%
def get_tier(raw):
    tier_dict = {}
    tier_flag = 0
    tier_start = 1
    
    for i, row in enumerate(raw, 0):
        if row.startswith('TIER'):
            key, value = row.split(': ')
            tier_dict[f'TIER {tier_start}'] = value.split('…')[0]
            tier_flag = 1
            tier_start += 1
        else:
            if tier_flag == 1:
                return tier_dict, raw[i:]

# %%
tier_dict, raw = get_tier(raw)

# %%
tier_dict
# Out:
# {'TIER 1': 'VERY REAL SUPERSTAR UPSIDE',
#  'TIER 2': 'REALIZABLE ALL-STAR UPSIDE',
#  'TIER 3': 'HIGH LEVERAGE STARTERS',
#  'TIER 4': 'UPSIDE SWINGS, POTENTIAL STARTERS ',
#  'TIER 5': 'ROTATION PLAYERS',
#  'TIER 6': 'SECOND ROUND FLIERS AND PRIORITY TWO WAYS',
#  'TIER 7': 'LOWER TIER TWO WAYS AND UNDRAFTED FLIERS'}

# %% [markdown]
# ## Get Big Board

# %%
def get_raw_big_board(raw):
    raw_bb_dict = {}
    bb_flag = 0
    bb_data = []
    
    for i, row in enumerate(raw, 0):
        if row.startswith('Rank'):
            raw_bb_dict['columns'] = row
            bb_flag = 1
        else:
            if bb_flag == 1:
                if row.split(' ')[0] != '100':
                    if ' 4 ' not in row:
                        bb_data.append(row)
                else:
                    bb_data.append(row)
                    raw_bb_dict['data'] = bb_data
                    return raw_bb_dict, raw[i+1:]

# %%
raw_bb_dict, raw = get_raw_big_board(raw)

# %%
def find_nth(haystack, needle, n):
    start = haystack.find(needle)
    while start >= 0 and n > 1:
        start = haystack.find(needle, start+len(needle))
        n -= 1
    return start

# %%
data_adj = []

for row in raw_bb_dict['data']:
    idx = find_nth(row, ' ', 3)
    row_adj = row[:idx] + ', ' + row[idx+1:]
    data_adj.append(row_adj.strip())
    
# Minor Edit
data_adj[11] = '12 Kira Lewis Jr., Alabama G 19 6-3 175 6-6 20'

# Update
raw_bb_dict['data'] = data_adj

# %%
def build_big_board(raw_bb_dict):
    columns = [col.replace('.', '').replace(',', '')
               for col in raw_bb_dict['columns'].strip().split(' ')][:-2]
    
    data = [row for row in raw_bb_dict['data']
            if len(row.split(' ')[0]) <= 3]
    
    processed_data = []
    for row in data:
        front, back = row.split(', ')
        row_adj = [front.split(' ')[0]] + [' '.join(front.split(' ')[1:])] + \
                  [' '.join(back.split(' ')[:-6])] + back.split(' ')[-6:]
        processed_data.append(row_adj)
    
    return pd.DataFrame(processed_data, columns=columns)

# %%
big_board = build_big_board(raw_bb_dict)

# %%
tier_breaks = ['LaMelo Ball', 'Onyeka Okongwu', 'Kira Lewis Jr.',
               'Tre Jones', 'Ty-Shon Alexander', 'Nate Knight', '']

tier_rec = []
tier = 1
idx = 0

for player in big_board.Player.values:
    if player == tier_breaks[idx]:
        idx += 1
        tier += 1
        tier_rec.append(tier)
    else:
        tier_rec.append(tier)
        
big_board['Tier'] = tier_rec

# %%
big_board = big_board.rename(columns={col:col.upper() for col in big_board.columns})\
                     .drop('SCOUTING', axis=1)
big_board
# Out:
#    RANK              PLAYER                   TEAM POSITION AGE HEIGHT WEIGHT  \
# 0     1         LaMelo Ball        Illawarra Hawks        G  19    6-6    175
# 1     2       James Wiseman                Memphis        C  19    7-1    245
# 2     3     Anthony Edwards                Georgia        G  19    6-5    225
# 3     4      Onyeka Okongwu                    USC      F/C  19    6-9    245
# 4     5         Isaac Okoro                 Auburn        W  19    6-6    225
# 5     6         Deni Avdija       Maccabi Tel Aviv      W/F  19    6-9    225
# 6     7   Tyrese Haliburton             Iowa State        G  20    6-5    175
# 7     8          Obi Toppin                 Dayton      F/C  22    6-9    230
# 8     9    Patrick Williams          Florida State        F  19    6-8    225
# 9    10       Killian Hayes         Ratiopharm Ulm        G  19    6-5    215
# 10   11       Devin Vassell          Florida State        W  20    6-6    195
# 11   12      Kira Lewis Jr.                Alabama        G  19    6-3    175
# 12   13        R.J. Hampton   New Zealand Breakers        G  19    6-5    185
# 13   14        Tyrese Maxey               Kentucky        G  20    6-3    200
# 14   15  Aleksej Pokusevski             Olympiacos      F/C  18    7-0    200
# 15   16          Saddiq Bey              Villanova      W/F  21    6-8    215
# 16   17       Aaron Nesmith             Vanderbilt        W  21    6-6    215
# 17   18           Tre Jones                   Duke        G  20    6-3    185
# 18   19        Desmond Bane                    TCU        W  22    6-5    215
# 19   20        Tyrell Terry               Stanford        G  20    6-3    170
# 20   21      Robert Woodard      Mississippi State      W/F  21    6-7    230
# 21   22          Josh Green                Arizona        W  20    6-6    215
# 22   23        Cole Anthony         North Carolina        G  20    6-3    190
# 23   24      Isaiah Stewart             Washington        C  19    6-9    245
# 24   25    Precious Achiuwa                Memphis      F/C  21    6-9    234
# 25   26       Malachi Flynn        San Diego State        G  22    6-1    185
# 26   27      Xavier Tillman         Michigan State        C  21    6-9    265
# 27   28        Grant Riller             Charleston        G  23    6-3    180
# 28   29     Leandro Bolmaro           FC Barcelona      W/F  20    6-8    200
# 29   30     Jaden McDaniels             Washington        F  20    6-9    200
# 30   31       Elijah Hughes               Syracuse        W  22    6-6    230
# 31   32         Jalen Smith               Maryland      F/C  20   6-10    225
# 32   33     Cassius Winston         Michigan State        G  22    6-1    195
# 33   34          Zeke Nnaji                Arizona      F/C  19   6-11    245
# 34   35        Theo Maledon                  ASVEL        G  19    6-5    185
# 35   36         Sam Merrill             Utah State        G  24    6-5    205
# 36   37    Payton Pritchard                 Oregon        G  22    6-2    200
# 37   38        Devon Dotson                 Kansas        G  21    6-2    185
# 38   39        Daniel Oturu              Minnesota        C  21   6-10    240
# 39   40      Killian Tillie                Gonzaga      F/C  22   6-10    220
# 40   41           Paul Reed                 DePaul      F/C  21    6-9    220
# 41   42        Jordan Nwora             Louisville        W  22    6-7    220
# 42   43         Mason Jones               Arkansas        W  22    6-5    205
# 43   44      Udoka Azubuike                 Kansas        C  21    7-0    260
# 44   45         Skylar Mays                    LSU        G  23    6-4    204
# 45   46   Immanuel Quickley               Kentucky        G  21    6-3    185
# 46   47        Nico Mannion                Arizona        G  19    6-3    190
# 47   48     Cassius Stanley                   Duke        W  21    6-6    200
# 48   49          Isaiah Joe               Arkansas        W  21    6-5    170
# 49   50   Ty-Shon Alexander              Creighton        G  22    6-3    200
# 50   51          Jay Scrubb          John A. Logan        W  20    6-6    185
# 51   52        Vernon Carey               Jr. Duke        C  19   6-10    270
# 52   53     Jahmi’us Ramsey             Texas Tech        G  19    6-4    195
# 53   54       Naji Marshall                 Xavier        W  22    6-7    220
# 54   55           Tyler Bey               Colorado      W/F  22    6-7    210
# 55   56           Yam Madar        Hapoel Tel Aviv        G  19    6-3    180
# 56   57       Markus Howard              Marquette        G  21   5-11    170
# 57   58    Justinian Jessup            Boise State        W  22    6-7    200
# 58   59       Lamar Stevens             Penn State      W/F  23    6-7    230
# 59   60        Reggie Perry      Mississippi State      F/C  20    6-9    250
# 60   61           Saben Lee             Vanderbilt        G  21    6-2    185
# 61   62         Nate Hinton                Houston        W  21    6-5    210
# 62   63       Kenyon Martin        Jr. IMG Academy        F  19    6-7    215
# 63   64    Abdoulaye N’Doye              AS Monaco      G/W  22    6-6    205
# 64   65         Nate Knight         William & Mary        C  23   6-10    235
# 65   66      Trevelin Queen       New Mexico State        W  23    6-6    190
# 66   67       Nick Richards               Kentucky        C  22    7-0    240
# 67   68     Marko Simonovic                   Mega        C  21   6-11    220
# 68   69       Trent Forrest          Florida State        G  22    6-5    205
# 69   70        Jalen Harris                 Nevada        G  22    6-4    195
# 70   71        Kaleb Wesson             Ohio State        C  21   6-10    250
# 71   72        Myles Powell             Seton Hall        G  23    6-2    195
# 72   73         Jordan Ford           Saint Mary’s        G  22    6-1    180
# 73   74        Nate Darling               Delaware        W  22    6-5    200
# 74   75         Malik Fitts           Saint Mary’s      W/F  23    6-7    230
# 75   76        Lamine Diane   Cal State Northridge        F  23    6-7    205
# 76   77       Ashton Hagans               Kentucky        G  21    6-3    190
# 77   78          Paul Eboua  Stella Azzurra/Pesaro      F/C  20    6-7    215
# 78   79           Josh Hall          Moravian Prep        F  20    6-6    195
# 79   80  Kristian Doolittle               Oklahoma        F  23    6-7    230
# 80   81        Jake Toolson                    BYU        W  24    6-5    205
# 81   82   Freddie Gillespie                 Baylor        C  23    6-9    245
# 82   83      Mamadi Diakite               Virginia      F/C  23    6-9    225
# 83   84          Karim Mané                 Vanier      G/W  20    6-6    190
# 84   85         C.J. Elleby       Washington State        W  20    6-6    200
# 85   86           Kouat Noi         Cairns Taipans        F  23    6-7    210
# 86   87       Dwayne Sutton             Louisville        W  23    6-5    215
# 87   88         Tres Tinkle           Oregon State      W/F  24    6-6    225
# 88   89      Caleb Homesley                Liberty        W  23    6-6    205
# 89   90      Kahlil Whitney               Kentucky        W  19    6-6    210
# 90   91         Isiaha Mike                    SMU      W/F  23    6-8    220
# 91   92        Yoeli Childs                    BYU        F  22    6-7    225
# 92   93        Anthony Lamb                Vermont        F  22    6-6    225
# 93   94        Breein Tyree            Mississippi        G  22    6-2    195
# 94   95       Tyrique Jones                 Xavier        C  23    6-9    240
# 95   96           Jon Teske               Michigan        C  23    7-1    260
# 96   97   Rayshaun Hammonds                Georgia        F  22    6-9    235
# 97   98     Emmitt Williams                    LSU        F  22    6-6    230
# 98   99      Omer Yurtseven             Georgetown        C  22    7-0    265
# 99  100       Kamar Baldwin                 Butler        G  23    6-1    190
#
#    WINGSPAN  TIER
# 0       6-9     2
# 1       7-6     2
# 2      6-10     2
# 3       7-1     3
# 4       6-9     3
# 5      6-10     3
# 6       6-7     3
# 7       N/A     3
# 8      6-11     3
# 9       6-6     3
# 10      6-9     3
# 11      6-6     4
# 12      6-7     4
# 13      6-6     4
# 14      7-3     4
# 15     6-11     4
# 16     6-10     4
# 17      6-5     5
# 18      6-4     5
# 19      6-2     5
# 20      7-2     5
# 21     6-10     5
# 22      6-4     5
# 23      7-5     5
# 24      7-1     5
# 25      N/A     5
# 26      7-2     5
# 27      6-5     5
# 28      N/A     5
# 29      7-0     5
# 30      6-8     5
# 31      7-2     5
# 32      6-6     5
# 33      7-2     5
# 34     6-11     5
# 35      N/A     5
# 36      6-6     5
# 37      6-3     5
# 38      7-2     5
# 39     6-10     5
# 40      7-2     5
# 41     6-10     5
# 42      6-8     5
# 43      7-7     5
# 44      6-6     5
# 45      6-8     5
# 46      6-3     5
# 47      6-7     5
# 48      6-8     5
# 49      6-8     6
# 50     6-10     6
# 51      7-1     6
# 52      6-6     6
# 53      7-1     6
# 54      7-1     6
# 55      N/A     6
# 56      6-0     6
# 57      N/A     6
# 58      6-9     6
# 59      7-0     6
# 60      N/A     6
# 61      N/A     6
# 62      6-7     6
# 63      7-2     6
# 64      7-2     7
# 65      6-7     7
# 66      7-2     7
# 67      N/A     7
# 68      6-8     7
# 69      6-7     7
# 70      7-4     7
# 71      6-7     7
# 72      N/A     7
# 73      N/A     7
# 74     6-11     7
# 75      N/A     7
# 76      6-8     7
# 77      7-4     7
# 78     6-11     7
# 79      N/A     7
# 80      N/A     7
# 81      7-4     7
# 82      7-4     7
# 83     6-11     7
# 84      6-7     7
# 85      7-1     7
# 86      N/A     7
# 87     6-11     7
# 88      N/A     7
# 89      7-0     7
# 90      N/A     7
# 91      7-0     7
# 92      N/A     7
# 93      N/A     7
# 94      7-0     7
# 95      N/A     7
# 96      N/A     7
# 97      N/A     7
# 98      7-0     7
# 99      N/A     7

# %% [markdown]
# ## Get Scouting Report

# %%
raw = [row.replace('\t', ' ') for row in raw]

# %%
def identify_scouting_report(raw, big_board):
    sr_dict = {}
    idx_breaks = []
    players_identified = []

    for player in big_board.PLAYER.values:
        for i, row in enumerate(raw, 0):
            if re.search(f'. {player}', row):
                if len(idx_breaks) == 0:
                    idx_breaks.append(i)
                    players_identified.append(player)
                    break
                if i > idx_breaks[-1]:
                    idx_breaks.append(i)
                    players_identified.append(player)
                    break
    
    idx_breaks = idx_breaks + [len(raw)]

    for i, player in enumerate(players_identified, 0):
        start = idx_breaks[i]
        end = idx_breaks[i+1]
        sr_dict[player] = [row.lstrip(' ') for row in raw[start:end]]
        
    # report
    print(f'# of players identified: {len(players_identified)}')
    
    return sr_dict

# %%
sr_dict = identify_scouting_report(raw, big_board)
# Out:
# # of players identified: 100

# %%
def check_categories(sc):
    n_err = 0
    for cat in ['STRENGTHS', 'WEAKNESSES', 'SUMMARY', 'GRADE']:
        if cat not in ' '.join(sc):
            print(cat)
            n_err += 1
    return n_err

# %%
players_removed = []

for player in sr_dict.keys():
    if check_categories(sr_dict[player]) >= 1:
        print(player)
        players_removed.append(player)
        print()
# Out:
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Saben Lee
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Nate Hinton
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Kenyon Martin
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Abdoulaye N’Doye
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Nate Knight
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Trevelin Queen
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Nick Richards
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Marko Simonovic
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Trent Forrest
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Jalen Harris
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Kaleb Wesson
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Myles Powell
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Jordan Ford
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Nate Darling
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Malik Fitts
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Lamine Diane
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Ashton Hagans
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Paul Eboua
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Josh Hall
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Kristian Doolittle
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Jake Toolson
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Freddie Gillespie
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Mamadi Diakite
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Karim Mané
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# C.J. Elleby
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Kouat Noi
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Dwayne Sutton
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Tres Tinkle
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Caleb Homesley
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Kahlil Whitney
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Isiaha Mike
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Yoeli Childs
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Anthony Lamb
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Breein Tyree
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Tyrique Jones
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Jon Teske
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Rayshaun Hammonds
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Emmitt Williams
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Omer Yurtseven
#
# STRENGTHS
# WEAKNESSES
# SUMMARY
# Kamar Baldwin

# %%
# Remove those players
big_board = big_board[~big_board['PLAYER'].isin(players_removed)].reset_index()\
                                                                 .drop('index', axis=1)
big_board
# Out:
#    RANK              PLAYER                  TEAM POSITION AGE HEIGHT WEIGHT  \
# 0     1         LaMelo Ball       Illawarra Hawks        G  19    6-6    175
# 1     2       James Wiseman               Memphis        C  19    7-1    245
# 2     3     Anthony Edwards               Georgia        G  19    6-5    225
# 3     4      Onyeka Okongwu                   USC      F/C  19    6-9    245
# 4     5         Isaac Okoro                Auburn        W  19    6-6    225
# 5     6         Deni Avdija      Maccabi Tel Aviv      W/F  19    6-9    225
# 6     7   Tyrese Haliburton            Iowa State        G  20    6-5    175
# 7     8          Obi Toppin                Dayton      F/C  22    6-9    230
# 8     9    Patrick Williams         Florida State        F  19    6-8    225
# 9    10       Killian Hayes        Ratiopharm Ulm        G  19    6-5    215
# 10   11       Devin Vassell         Florida State        W  20    6-6    195
# 11   12      Kira Lewis Jr.               Alabama        G  19    6-3    175
# 12   13        R.J. Hampton  New Zealand Breakers        G  19    6-5    185
# 13   14        Tyrese Maxey              Kentucky        G  20    6-3    200
# 14   15  Aleksej Pokusevski            Olympiacos      F/C  18    7-0    200
# 15   16          Saddiq Bey             Villanova      W/F  21    6-8    215
# 16   17       Aaron Nesmith            Vanderbilt        W  21    6-6    215
# 17   18           Tre Jones                  Duke        G  20    6-3    185
# 18   19        Desmond Bane                   TCU        W  22    6-5    215
# 19   20        Tyrell Terry              Stanford        G  20    6-3    170
# 20   21      Robert Woodard     Mississippi State      W/F  21    6-7    230
# 21   22          Josh Green               Arizona        W  20    6-6    215
# 22   23        Cole Anthony        North Carolina        G  20    6-3    190
# 23   24      Isaiah Stewart            Washington        C  19    6-9    245
# 24   25    Precious Achiuwa               Memphis      F/C  21    6-9    234
# 25   26       Malachi Flynn       San Diego State        G  22    6-1    185
# 26   27      Xavier Tillman        Michigan State        C  21    6-9    265
# 27   28        Grant Riller            Charleston        G  23    6-3    180
# 28   29     Leandro Bolmaro          FC Barcelona      W/F  20    6-8    200
# 29   30     Jaden McDaniels            Washington        F  20    6-9    200
# 30   31       Elijah Hughes              Syracuse        W  22    6-6    230
# 31   32         Jalen Smith              Maryland      F/C  20   6-10    225
# 32   33     Cassius Winston        Michigan State        G  22    6-1    195
# 33   34          Zeke Nnaji               Arizona      F/C  19   6-11    245
# 34   35        Theo Maledon                 ASVEL        G  19    6-5    185
# 35   36         Sam Merrill            Utah State        G  24    6-5    205
# 36   37    Payton Pritchard                Oregon        G  22    6-2    200
# 37   38        Devon Dotson                Kansas        G  21    6-2    185
# 38   39        Daniel Oturu             Minnesota        C  21   6-10    240
# 39   40      Killian Tillie               Gonzaga      F/C  22   6-10    220
# 40   41           Paul Reed                DePaul      F/C  21    6-9    220
# 41   42        Jordan Nwora            Louisville        W  22    6-7    220
# 42   43         Mason Jones              Arkansas        W  22    6-5    205
# 43   44      Udoka Azubuike                Kansas        C  21    7-0    260
# 44   45         Skylar Mays                   LSU        G  23    6-4    204
# 45   46   Immanuel Quickley              Kentucky        G  21    6-3    185
# 46   47        Nico Mannion               Arizona        G  19    6-3    190
# 47   48     Cassius Stanley                  Duke        W  21    6-6    200
# 48   49          Isaiah Joe              Arkansas        W  21    6-5    170
# 49   50   Ty-Shon Alexander             Creighton        G  22    6-3    200
# 50   51          Jay Scrubb         John A. Logan        W  20    6-6    185
# 51   52        Vernon Carey              Jr. Duke        C  19   6-10    270
# 52   53     Jahmi’us Ramsey            Texas Tech        G  19    6-4    195
# 53   54       Naji Marshall                Xavier        W  22    6-7    220
# 54   55           Tyler Bey              Colorado      W/F  22    6-7    210
# 55   56           Yam Madar       Hapoel Tel Aviv        G  19    6-3    180
# 56   57       Markus Howard             Marquette        G  21   5-11    170
# 57   58    Justinian Jessup           Boise State        W  22    6-7    200
# 58   59       Lamar Stevens            Penn State      W/F  23    6-7    230
# 59   60        Reggie Perry     Mississippi State      F/C  20    6-9    250
#
#    WINGSPAN  TIER
# 0       6-9     2
# 1       7-6     2
# 2      6-10     2
# 3       7-1     3
# 4       6-9     3
# 5      6-10     3
# 6       6-7     3
# 7       N/A     3
# 8      6-11     3
# 9       6-6     3
# 10      6-9     3
# 11      6-6     4
# 12      6-7     4
# 13      6-6     4
# 14      7-3     4
# 15     6-11     4
# 16     6-10     4
# 17      6-5     5
# 18      6-4     5
# 19      6-2     5
# 20      7-2     5
# 21     6-10     5
# 22      6-4     5
# 23      7-5     5
# 24      7-1     5
# 25      N/A     5
# 26      7-2     5
# 27      6-5     5
# 28      N/A     5
# 29      7-0     5
# 30      6-8     5
# 31      7-2     5
# 32      6-6     5
# 33      7-2     5
# 34     6-11     5
# 35      N/A     5
# 36      6-6     5
# 37      6-3     5
# 38      7-2     5
# 39     6-10     5
# 40      7-2     5
# 41     6-10     5
# 42      6-8     5
# 43      7-7     5
# 44      6-6     5
# 45      6-8     5
# 46      6-3     5
# 47      6-7     5
# 48      6-8     5
# 49      6-8     6
# 50     6-10     6
# 51      7-1     6
# 52      6-6     6
# 53      7-1     6
# 54      7-1     6
# 55      N/A     6
# 56      6-0     6
# 57      N/A     6
# 58      6-9     6
# 59      7-0     6

# %%
# Remove those players
print(len(sr_dict))
for player in players_removed:
    del sr_dict[player]
print(len(sr_dict))
# Out:
# 100
# 60

# %% [markdown]
# ### Clean Scouting Report

# %%
def clean_scouting_report(sr):
    school = sr[0].split(' | ')[2]
    idx_breaks = []
    
    cats = ['STRENGTHS', 'WEAKNESSES', 'SUMMARY', 'GRADE']
    
    for cat in cats:
        for i, row in enumerate(sr, 0):
            if row.startswith(f'{cat}:'):
                idx_breaks.append(i)
                break
                
    idx_breaks = idx_breaks + [len(sr)]
    
    output_dict = {}
    
    for i, cat in enumerate(cats, 0):
        start = idx_breaks[i]
        end = idx_breaks[i+1]
        content = [row.strip('-') for row in sr[start:end] 
                   if row.endswith(' ') or row.endswith('.') or row.endswith('-')]
        content = [row for row in content
                   if re.search(f'^20..-.. {school}', row) is None 
                   and re.search('^20..-..', row) is None
                   and row.strip(' ') != 'NCAA']
        mask = [row for row in content if row.strip().isdigit()]
        content = [row for row in content if row not in mask]
        content[0] = content[0].replace(f'{cat}:', '').lstrip()
        output_dict[cat] = ''.join(content)

    return output_dict

# %%
clean_scouting_report(sr_dict['Tyrese Haliburton'])
# Out:
# {'STRENGTHS': 'His feel for the game is just absolutely off the charts. Has a case for having the highest basketball IQ in this draft class. Makes the right decision all the time. Keeps the offense in flow. That starts as a ballhandler. Haliburton is an extremely high-level passer out of all situations. Great with head-man passes in transition. Sees everything and plays unselfishly. The game is not about his numbers despite the fact that he put up great numbers this year. Despite not exactly being a high-level pick-and-roll scorer, he can make every pass in the book as a pick-and-roll passer. He reads the defense exceptionally well. Takes advantage of exactly what he’s presented and has an incredible internal process for finding the right decision. His poise is remarkable for a guy who played both of his seasons essentially as a teenager. There’s a real patience and calm to everything he does. Defenses can’t really speed him up and his size for the position makes it tougher to defend him with lead guards. Very fluid in the way he changes paces. At 6-foot-5 with a 6-foot-7 wingspan, has elite size to see over the top of defenders and make plays when guarded by a true lead.  Shoots it exceedingly well off the catch. Has tremendous touch on his jumper. Hit 49.3 percent of his catch-and-shoot jumpers this year, with all of the makes being 3s. That gave him a pretty outrageous 73.9 effective field goal percentage on such shots. According to Synergy, that was the sixth-best mark among the 623 players nationally to take at least three such shots per game. Within the top-100, only Aaron Nesmith was better. Has a bit of a strange release. It’s a push shot that comes from out in front of his face with a low release point. However, he makes up for those awkward mechanics by having exceptional range on it. Already confident from well beyond NBA range. If he gets even a small amount of space to fire, he can knock it down. This should allow him to translate exceedingly well playing next to a star on-ball wing who takes up a lot of offensive possessions. Also really excels as a passer and playmaker out of advantage situations where he can pump fake and get into the teeth of the defense after attacking a closeout. In general, if you get Haliburton downhill either out on the break or in an advantage spot, he’s going to be tough to deal with. If he beats his first defender, he also has a really nice little developing floater game. Made 45 percent of those shots this season. Does a great job shielding the ball from defenders then using his length to extend and release.  Also, a high-level defender in a team concept. Largely just a 1-2 defender right now because of his lack of strength but knows exactly where he needs to be, rotationally, at all times. Has his arms consistently outstretched looking for deflections, which allows him to play longer than he actually is. Reads what the ballhandler wants to do and does a great job harassing and disrupting with his length on ball. A bit of a gambler but tends to get there when he gambles. Has a good sense of when to take those chances.  ',
#  'WEAKNESSES': 'I’m not convinced Haliburton has enough ability to consistently separate as a lead ballhandler at the next level. Great footwork and changes pace well but lacks a degree of burst and shake. Doesn’t seem to be wildly comfortable with his left hand. Much better athlete if he receives the ball in an advantage situation where he’s either able to take advantage of defenders already on the move, or when he’s already on the move himself. Great passer who sees everything, but consistently leaves his feet prior to passing, which could lead to further turnovers in the NBA because you automatically put a clock on yourself when you leave your feet. Also doesn’t really get to the rim all that often. Only 1.5 attempts at the rim in the half court per game this season according to Synergy. Made those shots when he got there with touch, but just doesn’t have the explosiveness to consistently get there right now. The good news is that the in-between game he has with the floater helps to make up for it, but he has to be able to get into the second level to take advantage of it.  Additionally, there is a concern about whether or not he’ll be a threat off of pull-ups at the next level. While he has great touch and shot well from 3, his mechanics aren’t suited to him being a high-volume pull-up threat. It’s tough for him to get shots off when he’s taking them off the bounce. Not really a late-shot-clock threat. Low release and long load time allow defenders to really contest him. Only made 28.1 percent of his pull-up jumpers this year according to Synergy, at a 34.2 effective field goal percentage. The two factors above contribute to real worries that he might not actually be a lead guard, but rather more of a secondary half court playmaker who can help you push tempo and make great reads in transition. That’s less valuable than a lead guard, but the fact that he has size and his game translates to playing off ball definitely gives him a higher floor than most lead guards.  Finally, his on-ball defense in general leaves something to be desired despite his ability to play disruptively with his hands. Can get driven a bit easier by quicker guards than you’d like to see. Can get leveraged by smaller guards who can get under his high center of gravity. Also has issues with his strength. In general, that might be his biggest concern. How much stronger can he get? Can he keep putting on enough strength to defend multiple positions? Will he be pushed around by stronger players on the ball as an offensive threat? As he gets stronger, will he add a bit of explosiveness?  ',
#  'SUMMARY': 'Haliburton is going to be a useful NBA player because few guys who think the game at the level that he does while maintaining the ball skills he does at 6foot-5 fail. He’s an elite passer, has tremendous touch and can play on the defensive side of the floor. Personally, I see him more as a combo guard who plays off the ball in the half court more than I see him as a lead. That’s okay with me, though. Imagine him playing the role of someone like Lonzo Ball with better touch and less strength. Ball isn’t quite a half court lead guard that you can trust to make plays on his own, but put him out there with Jrue Holiday as a half court shot creator and he becomes an incredibly effective, high-level role player. Haliburton will help create a ton of transition opportunities, will contribute to positive defenses and likely will hit shots off the catch. That’s a hell of a floor for a prospect. If his strength ever comes along and he keeps developing that left hand and change of direction handle while morphing into a lead guard? He has a real shot to become a top-half of the league point guard. Even if that doesn’t happen though — and I think it’s probably a long shot that it does — Haliburton is the kind of player that I absolutely want on my team if my goal is to win basketball games. He’s smart, he’s a great teammate and he plays the game the right way while putting all of his teammates in better positions to succeed.   ',
#  'GRADE': 'Lottery  '}

# %%
for key in sr_dict:
    sr_dict[key] = clean_scouting_report(sr_dict[key])

# %%
sr_dict['LaMelo Ball']
# Out:
# {'STRENGTHS': 'Everything starts with Ball’s elite-level feel for the game. He sees and understands the game in a way that few teenagers do. That displays itself most in his passing ability. Ball is tremendous at reading the second and third levels of the defense and making anticipatory passing reads based off how those defenders play in help. He sees nearly every pass that is available, and on top of it has the talent to execute said passes from a wide variety of angles. He’s an elite-level live-dribble passer. He can throw one-handed whip passes from either hand. His ability to hit the cross-corner kickout will translate well given how available that pass tends to be in the NBA. He can hit pocket bounce passes to rollers and weights lobs perfectly. Additionally, despite a relatively wild style of play, Ball tends to relatively limit turnovers because of that basketball IQ and the way that he can control the ball.  Indeed, Ball is a tremendous ballhandler who can create at an extremely high level. He can change tempos and paces without getting flustered. He plays with much better bend than Lonzo, allowing him to more easily break down defenses. His poise in ball-screens is tremendous, as he can wait for the help to develop while keeping the ball away from defenders. He’s tremendous at using his body, despite a lack of strength, to keep defenders on his back or hip in order to put pressure on the defense in the paint. On top of that poise, Ball also has a wicked, quick crossover and the ability to get low and create separation. He has very fluid hips, which allow him to open up and quickly blow-by with speed with a degree of deception. He’s not an elite athlete, but this mix of poise, patience, change of tempo and change of direction allows him to really get separation whenever he wants as an attacker, with or without ball-screens. He gets into the lane and forces defenders into tough situations more than any other player in this class, allowing him to score despite still working through his efficiency.  At 6-foot-6, Ball has elite size for the lead guard position. On top of that, Ball is also a great rebounder for a guard and his elite level IQ does showcase itself at times on defense. He makes good reads and rotations when engaged and can shoot passing lanes for turnovers and transition opportunities. There is upside for him to be a defensive playmaker, even though he was ineffectual there this season. ',
#  'WEAKNESSES': 'The defense isn’t a sure thing, though, because Ball doesn’t quite engage at a high enough level on that end. Having never been held accountable defensively prior to this season, Ball faced an adjustment and he didn’t always meet the challenge. Sometimes he’d get caught wiping his feet while he was supposed to be tagging a roller on the back side. Sometimes, he’d hunt rebounds to start the break and ball-watch instead of staying in solid position. His overall intensity and mindset must improve on that end.  The big issue on offense is a question of his jump shot. Ball hit just 25 percent from 3 this season, although there is reason to believe he is a better shooter than that. Really, the low percentage comes down to shot selection above all. There are times that he’ll pull up with 20 seconds left on the shot clock for a contested 30-footer for no good reason. And overall, his jumper does have some mechanical work that needs done, starting with his footwork and base off the catch. However, he can hit shots coming off of screens if defenders go under on him. He’s also grown about seven inches in the last two years, which has led to an elongation of his frame and body. He’s skinnier and the trajectory on his jumper has changed. As he gets more comfortable with his frame and gets stronger, he should become a more consistent shooter, more capable of repeating his mechanics. ',
#  'SUMMARY': 'Ball should enter the NBA as one of the most creative passers in the league from Day 1. He should be able to make plays at a high level early because of his basketball IQ, his live dribble passing and his experience playing up in competition level from a young and age professional experience in the NBL, which is a stronger, more physical league than the NCAA. His ability to be an elite-level distributor and creator who can get separation from defenders and break down defenses at this age gives him a higher upside than anyone in the class. Whether or not he meets that upside will be dependent on how the defense and the shot develop over the next three years. If Ball is willing to put in work and become a 34 to 36 percent 3-point shooter — something I absolutely don’t think is out of the question if he’s more willing to take better shots and excise the awful shot selection he exhibits at times — he will become an All-Star caliber offensive player. And if he’s willing to showcase more engagement on the defensive end in the NBA, he has the tools to reach a positive level on that side of the floor, too. Think of the upside here as a bigger prime Rajon Rondo, a player I think was on a Hall of Fame trajectory prior to injuries and the downside as being a low-level starting point guard who never totally comes through with enough efficiency. ',
#  'GRADE': 'Top-five in a normal draft. '}

# %% [markdown]
# ## Assemble Data

# %% [markdown]
# ### Add Scouting Report

# %%
cats = ['STRENGTHS', 'WEAKNESSES', 'SUMMARY']
for cat in cats:
    big_board[cat] = big_board['PLAYER'].apply(lambda x: sr_dict[x][cat])
    
big_board = big_board.rename(columns={cat: cat.upper() for cat in cats})

# %% [markdown]
# ### Add Tier Description

# %%
tier_dict
# Out:
# {'TIER 1': 'VERY REAL SUPERSTAR UPSIDE',
#  'TIER 2': 'REALIZABLE ALL-STAR UPSIDE',
#  'TIER 3': 'HIGH LEVERAGE STARTERS',
#  'TIER 4': 'UPSIDE SWINGS, POTENTIAL STARTERS ',
#  'TIER 5': 'ROTATION PLAYERS',
#  'TIER 6': 'SECOND ROUND FLIERS AND PRIORITY TWO WAYS',
#  'TIER 7': 'LOWER TIER TWO WAYS AND UNDRAFTED FLIERS'}

# %%
big_board['TIER_DESCRIP'] = big_board['TIER'].apply(lambda x: tier_dict[f'TIER {x}'])

# %%
big_board.head()
# Out:
#   RANK           PLAYER             TEAM POSITION AGE HEIGHT WEIGHT WINGSPAN  \
# 0    1      LaMelo Ball  Illawarra Hawks        G  19    6-6    175      6-9
# 1    2    James Wiseman          Memphis        C  19    7-1    245      7-6
# 2    3  Anthony Edwards          Georgia        G  19    6-5    225     6-10
# 3    4   Onyeka Okongwu              USC      F/C  19    6-9    245      7-1
# 4    5      Isaac Okoro           Auburn        W  19    6-6    225      6-9
#
#    TIER                                          STRENGTHS  \
# 0     2  Everything starts with Ball’s elite-level feel...
# 1     2  Physical tools are off the charts. Has a 7-foo...
# 2     2  Utterly elite physical tools for the shooting ...
# 3     3  All starts with his mentality. This dude plays...
# 4     3  The place to start is he just makes teams bett...
#
#                                           WEAKNESSES  \
# 0  The defense isn’t a sure thing, though, becaus...
# 1  Has done a great job working on his physical s...
# 2  I’m not entirely sure where to put Edwards’ sh...
# 3  While he’s effective in the roles noted above,...
# 4  The jump shot is kind of a mess. It’s inconsis...
#
#                                              SUMMARY  \
# 0  Ball should enter the NBA as one of the most c...
# 1  Wiseman is a prospect that has elite skills an...
# 2  This is all about tools in the case of Edwards...
# 3  It’s hard to find centers who can close games ...
# 4  Ultimately, everything hinges on the shot. If ...
#
#                  TIER_DESCRIP
# 0  REALIZABLE ALL-STAR UPSIDE
# 1  REALIZABLE ALL-STAR UPSIDE
# 2  REALIZABLE ALL-STAR UPSIDE
# 3      HIGH LEVERAGE STARTERS
# 4      HIGH LEVERAGE STARTERS

# %% [markdown]
# ## Save output

# %%
big_board.to_csv('../processed_csv/2020.csv', index=False)
