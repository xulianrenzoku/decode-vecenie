# %%
import os
import re
import pandas as pd
import numpy as np
from tika import parser

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_rows', 100)

# %%
os.listdir('../processed_pdf')
# Out:
# ['2020.pdf', '2021.pdf', '2023.pdf', '2022.pdf']

# %% [markdown]
# ## Read Raw Data

# %%
raw = parser.from_file('../processed_pdf/2021.pdf')
# print(raw['content'])

# %%
raw = raw['content'].split('\n')

# %%
print(len(raw))
raw = [row for row in raw if row != '']
print(len(raw))
# Out:
# 9526
# 7502

# %% [markdown]
# ## Get Tier

# %%
def get_tier(raw):
    tier_dict = {}
    tier_flag = 0
    
    for i, row in enumerate(raw, 0):
        if row.startswith('Tier'):
            key, value = row.split(': ')
            tier_dict[key] = value
            tier_flag = 1
        else:
            if tier_flag == 1:
                return tier_dict, raw[i:]

# %%
tier_dict, raw = get_tier(raw)

# %%
tier_dict
# Out:
# {'Tier 1': 'Superstar Upside',
#  'Tier 2': 'All-Star Upside',
#  'Tier 3': 'High Leverage Starters',
#  'Tier 4': 'Potential Starters',
#  'Tier 5': 'Rotation Players',
#  'Tier 6': '2nd Rd. Fliers ',
#  'Tier 7': 'Undrafted Fliers ',
#  'Tier 8': 'Exhibit 10'}

# %% [markdown]
# ## Get Big Board

# %%
def get_raw_big_board(raw):
    raw_bb_dict = {}
    bb_flag = 0
    bb_data = []
    
    for i, row in enumerate(raw, 0):
        if row.startswith('RANK'):
            raw_bb_dict['columns'] = row
            bb_flag = 1
        else:
            if bb_flag == 1:
                if row.split(' ')[0] != '100':
                    if row != '2 0 2 1  N B A  D R A F T  G U I D E 4 ':
                        bb_data.append(row)
                else:
                    bb_data.append(row)
                    raw_bb_dict['data'] = bb_data
                    return raw_bb_dict, raw[i+1:]

# %%
raw_bb_dict, raw = get_raw_big_board(raw)

# %%
def adjust_name(n):
    comps = n.strip().split(' ')
    adj_comps = [f'{comp[0]}{comp[1:].lower()}' for comp in comps]
    return ' '.join(adj_comps)

# %%
def build_big_board(raw_bb_dict):
    columns = [col.replace('.', '').replace(',', '')
               for col in raw_bb_dict['columns'].split(' ')]
    columns = [col for col in columns if col != '']
    
    data = [row for row in raw_bb_dict['data']
            if len(row.split(' ')[0]) <= 3]
    
    processed_data = []
    for row in data:
        front, back = row.split(', ')
        back = back.strip()
        row_adj = [front.split(' ')[0]] + [' '.join(front.split(' ')[1:])] + \
                  [' '.join(back.split(' ')[:-5])] + back.split(' ')[-5:]
        row_adj[1] = adjust_name(row_adj[1]) # adjust players' names
        row_adj[2] = adjust_name(row_adj[2]) # adjust school names
        processed_data.append(row_adj)
    
    return pd.DataFrame(processed_data, columns=columns)

# %%
big_board = build_big_board(raw_bb_dict)

# %%
# Minor Edit
names_dict = {'Jeremiah Robinson-earl': 'Jeremiah Robinson-Earl',
              "Nah'shon “bones” Hyland": "Nah’Shon “Bones” Hyland",
              "Day'ron Sharpe": "Day’Ron Sharpe",
              'B.j. Boston': 'B.J. Boston',
              'Jt Thor': 'JT Thor',
              'Ej Onu': 'EJ Onu',
              'Dj Steward': 'DJ Steward',
              'Aj Lawson': 'A.J. Lawson',
              'D.j. Stewart Jr.': 'D.J. Stewart Jr.',
              'Rj Nembhard': 'RJ Nembhard',
              'M.j. Walker': 'M.J. Walker',
              'Jaquori Mclaughlin': 'JaQuori McLaughlin',
              'Macio Teague': 'MaCio Teague', 
              'Dejon Jarreau': 'DeJon Jarreau',
              'Raiquan Gray' :'RaiQuan Gray', 
              'Mckinley Wright Iv': 'McKinley Wright IV',
              'Miles Mcbride': 'Miles McBride',
              'Trey Murphy Iii': 'Trey Murphy III'}
big_board['PLAYER'] = big_board['PLAYER'].apply(lambda x: names_dict.get(x, x))

# %%
schools_dict = {'Tcu': 'TCU', 'Lsu': 'LSU', 'Vcu': 'VCU',
                'Usc': 'USC', 'Uc Santa Barbara': 'UC Santa Barbara',
                'Ucla': 'UCLA', 'Loyola (md)': 'Loyola (MD)'}
big_board['SCHOOL/TEAM'] = big_board['SCHOOL/TEAM'].apply(lambda x: schools_dict.get(x, x))

# %%
big_board
# Out:
#    RANK                   PLAYER        SCHOOL/TEAM  POS AGE    HT  WING TIER
# 0     1          Cade Cunningham     Oklahoma State  G/W  19   6-8   7-1    1
# 1     2              Jalen Suggs            Gonzaga    G  20   6-4   6-6    2
# 2     3              Evan Mobley                USC    C  20   7-0   7-4    2
# 3     4              Jalen Green    G League Ignite    G  19   6-5   6-8    2
# 4     5         Jonathan Kuminga    G League Ignite    W  18   6-8   7-0    3
# 5     6           Scottie Barnes      Florida State    F  19   6-9   7-3    3
# 6     7              Moses Moody           Arkansas    W  19   6-6   7-1    4
# 7     8           Alperen Sengun           Besiktas    C  19  6-10   7-0    4
# 8     9          James Bouknight        Connecticut    W  20   6-5   6-8    4
# 9    10          Davion Mitchell             Baylor    G  22   6-1   6-4    4
# 10   11             Usman Garuba        Real Madrid    C  19   6-8   7-2    4
# 11   12              Josh Giddey     Adelaide 36ers    W  18   6-8   N/A    4
# 12   13             Chris Duarte             Oregon    G  24   6-6   6-7    4
# 13   14             Franz Wagner           Michigan  W/F  19   6-9   N/A    4
# 14   15          Ziaire Williams           Stanford    W  19   6-9  6-10    4
# 15   16          Trey Murphy III           Virginia  W/F  21   6-9   7-0    4
# 16   17             Jared Butler             Baylor    G  20   6-3   6-4    4
# 17   18            Corey Kispert            Gonzaga    W  22   6-7   6-7    4
# 18   19                Kai Jones              Texas    C  20  6-11   7-2    4
# 19   20           Jaden Springer          Tennessee    G  18   6-4   6-8    4
# 20   21             Keon Johnson          Tennessee  G/W  19   6-5   6-7    4
# 21   22            Miles McBride      West Virginia    G  20   6-2   6-9    4
# 22   23              Ayo Dosunmu           Illinois    G  21   6-5  6-10    5
# 23   24           Sharife Cooper             Auburn    G  20   6-0   N/A    5
# 24   25            Jalen Johnson               Duke    F  19   6-9   7-0    5
# 25   26           Isaiah Jackson           Kentucky    C  19  6-10   7-4    5
# 68   69             Matt Coleman              Texas    G  23   6-1   N/A    7
# 69   70              Chris Smith               UCLA    W  21   6-9   N/A    7
# 70   71               John Petty            Alabama    W  22   6-6  6-10    7
# 71   72            Dalano Banton           Nebraska  G/F  21   6-9  6-10    7
# 72   73                   EJ Onu      Shawnee State    C  22  6-11   7-8    7
# 73   74             Carlik Jones         Louisville    G  23   6-1   6-5    7
# 74   75          Trendon Watford                LSU    F  20   6-9   7-2    7
# 75   76                 Jay Huff           Virginia    C  22   7-2   7-3    7
# 76   77            Scottie Lewis            Florida    W  21   6-5   7-0    7
# 77   78               DJ Steward               Duke    G  19   6-2   6-7    7
# 78   79              Daishen Nix    G League Ignite    G  19   6-4   6-7    7
# 79   80           Eugene Omoruyi             Oregon    F  24   6-7   7-1    7
# 80   81              A.J. Lawson     South Carolina    G  21   6-7   6-7    7
# 81   82        Marcus Zegarowski          Creighton    G  22   6-2   6-3    7
# 82   83            Jose Alvarado       Georgia Tech    G  23   6-0   6-1    7
# 83   84           Derrick Alston        Boise State    W  23   6-9   7-1    7
# 84   85           Jordan Schakel    San Diego State    W  23   6-5   N/A    8
# 85   86         D.J. Stewart Jr.  Mississippi State    W  22   6-6   7-0    8
# 86   87              RJ Nembhard                TCU    G  22   6-5  6-10    8
# 87   88            Mitch Ballock          Creighton    W  23   6-5   N/A    8
# 88   89            Matt Mitchell    San Diego State    W  22   6-6   6-8    8
# 89   90              M.J. Walker      Florida State    W  23   6-5   6-9    8
# 90   91           Chaundee Brown           Michigan    W  22   6-6   6-8    8
# 91   92     Duane Washington Jr.         Ohio State    G  21   6-4   6-8    8
# 92   93            Javonte Smart                LSU    G  20   6-4   6-8    8
# 93   94             MaCio Teague             Baylor    G  24   6-3  6-10    8
# 94   95            DeJon Jarreau            Houston    G  23   6-5   N/A    8
# 95   96            Arnas Velicka       Braunschweig    G  21   6-4   N/A    8
# 96   97       JaQuori McLaughlin   UC Santa Barbara    G  23   6-4   6-5    8
# 97   98                Dru Smith           Missouri    G  23   6-3   N/A    8
# 98   99           Ethan Thompson       Oregon State    G  22   6-5   N/A    8
# 99  100               Amar Sylla           Oostende    F  19   6-9   7-2    8

# %% [markdown]
# ## Get Scouting Report

# %% [markdown]
# ### Build Raw Dict

# %%
print(len(raw))
raw = [row.replace('\t', ' ') for row in raw if row != ' ']
print(len(raw))
# Out:
# 7306
# 6088

# %%
def identify_scouting_report(raw, big_board):
    sr_dict = {}
    idx_breaks = []
    players_identified = []

    for player in big_board.PLAYER.values:
        for i, row in enumerate(raw, 0):
            if row.strip().endswith(player):
                if len(idx_breaks) == 0:
                    idx_breaks.append(i)
                    players_identified.append(player)
                    break
                if i > idx_breaks[-1]:
                    idx_breaks.append(i)
                    players_identified.append(player)
                    break
    
    idx_breaks = idx_breaks + [len(raw)]

    for i, player in enumerate(players_identified, 0):
        start = idx_breaks[i]
        end = idx_breaks[i+1]
        sr_dict[player] = [row.lstrip(' ') for row in raw[start:end]]
        
    # report
    print(f'# of players identified: {len(players_identified)}')
    
    return sr_dict

# %%
sr_dict = identify_scouting_report(raw, big_board)
# Out:
# # of players identified: 100

# %%
def check_categories(sc):
    n_err = 0
    for cat in ['Background', 'Strengths', 'Weaknesses', 'Summary']:
        if cat not in [row.strip() for row in sc]:
            print(cat)
            n_err += 1
    return n_err

# %%
# Minor Edit
sr_dict['Scottie Barnes'][2] = 'Background '

# %%
players_removed = []

for player in sr_dict.keys():
    if check_categories(sr_dict[player]) >= 1:
        print(player)
        players_removed.append(player)
        print()
# Out:
# Strengths
# Weaknesses
# EJ Onu
#
# Strengths
# Weaknesses
# Eugene Omoruyi
#
# Strengths
# Weaknesses
# A.J. Lawson
#
# Strengths
# Weaknesses
# Marcus Zegarowski
#
# Strengths
# Weaknesses
# Jose Alvarado
#
# Strengths
# Weaknesses
# Derrick Alston
#
# Strengths
# Weaknesses
# Jordan Schakel
#
# Strengths
# Weaknesses
# D.J. Stewart Jr.
#
# Strengths
# Weaknesses
# RJ Nembhard
#
# Strengths
# Weaknesses
# Mitch Ballock
#
# Strengths
# Weaknesses
# Matt Mitchell
#
# Strengths
# Weaknesses
# M.J. Walker
#
# Strengths
# Weaknesses
# Chaundee Brown
#
# Strengths
# Weaknesses
# Duane Washington Jr.
#
# Strengths
# Weaknesses
# Javonte Smart
#
# Strengths
# Weaknesses
# MaCio Teague
#
# Strengths
# Weaknesses
# DeJon Jarreau
#
# Strengths
# Weaknesses
# Arnas Velicka
#
# Strengths
# Weaknesses
# JaQuori McLaughlin
#
# Strengths
# Weaknesses
# Dru Smith
#
# Strengths
# Weaknesses
# Ethan Thompson
#
# Strengths
# Weaknesses
# Amar Sylla

# %%
# Remove those players
big_board = big_board[~big_board['PLAYER'].isin(players_removed)].reset_index()\
                                                                 .drop('index', axis=1)
big_board
# Out:
#    RANK                   PLAYER       SCHOOL/TEAM  POS AGE    HT  WING TIER
# 0     1          Cade Cunningham    Oklahoma State  G/W  19   6-8   7-1    1
# 1     2              Jalen Suggs           Gonzaga    G  20   6-4   6-6    2
# 2     3              Evan Mobley               USC    C  20   7-0   7-4    2
# 3     4              Jalen Green   G League Ignite    G  19   6-5   6-8    2
# 4     5         Jonathan Kuminga   G League Ignite    W  18   6-8   7-0    3
# 5     6           Scottie Barnes     Florida State    F  19   6-9   7-3    3
# 6     7              Moses Moody          Arkansas    W  19   6-6   7-1    4
# 7     8           Alperen Sengun          Besiktas    C  19  6-10   7-0    4
# 8     9          James Bouknight       Connecticut    W  20   6-5   6-8    4
# 9    10          Davion Mitchell            Baylor    G  22   6-1   6-4    4
# 10   11             Usman Garuba       Real Madrid    C  19   6-8   7-2    4
# 11   12              Josh Giddey    Adelaide 36ers    W  18   6-8   N/A    4
# 12   13             Chris Duarte            Oregon    G  24   6-6   6-7    4
# 13   14             Franz Wagner          Michigan  W/F  19   6-9   N/A    4
# 56   57               Luka Garza              Iowa    C  22  6-11   7-2    6
# 57   58           Filip Petrusev              Mega    C  21  6-11  6-11    6
# 58   59           Charles Bassey  Western Kentucky    C  20  6-10   7-3    6
# 59   60             Matthew Hurt              Duke    F  21   6-9   6-9    6
# 60   61              Aamir Simms           Clemson    F  22   6-9   7-0    7
# 61   62             RaiQuan Gray     Florida State    F  21   6-8  6-11    6
# 62   63               David Duke        Providence    G  21   6-5   6-9    7
# 63   64           Marcus Garrett            Kansas    G  22   6-6  6-10    7
# 64   65            Aaron Wiggins          Maryland    W  22   6-6  6-10    7
# 65   66       Vrenz Bleijenbergh           Antwerp    W  20   6-9   N/A    7
# 66   67               Sam Hauser          Virginia    F  23   6-8   6-9    7
# 67   68                Yves Pons         Tennessee  F/C  22   6-7   7-1    7
# 68   69             Matt Coleman             Texas    G  23   6-1   N/A    7
# 69   70              Chris Smith              UCLA    W  21   6-9   N/A    7
# 70   71               John Petty           Alabama    W  22   6-6  6-10    7
# 71   72            Dalano Banton          Nebraska  G/F  21   6-9  6-10    7
# 72   74             Carlik Jones        Louisville    G  23   6-1   6-5    7
# 73   75          Trendon Watford               LSU    F  20   6-9   7-2    7
# 74   76                 Jay Huff          Virginia    C  22   7-2   7-3    7
# 75   77            Scottie Lewis           Florida    W  21   6-5   7-0    7
# 76   78               DJ Steward              Duke    G  19   6-2   6-7    7
# 77   79              Daishen Nix   G League Ignite    G  19   6-4   6-7    7

# %%
# Remove those players
print(len(sr_dict))
for player in players_removed:
    del sr_dict[player]
print(len(sr_dict))
# Out:
# 100
# 78

# %% [markdown]
# ### Clean Scouting Report

# %%
def clean_scouting_report(sr):
    school = sr[1].split(' | ')[1]
    idx_breaks = []
    
    cats = ['Strengths', 'Weaknesses', 'Summary']
    
    for cat in cats:
        for i, row in enumerate(sr, 0):
            if row.strip() == cat:
                idx_breaks.append(i)
                break
                
    idx_breaks = idx_breaks + [len(sr)]
    
    output_dict = {}
    
    for i, cat in enumerate(cats, 0):
        start = idx_breaks[i]
        end = idx_breaks[i+1]
        content = [row.strip('-') for row in sr[start:end] 
                   if row.endswith(' ') or row.endswith('.') or row.endswith('-')]
        content = [row for row in content
                   if re.search(f'^20..-.. {school}', row) is None 
                   and re.search('^20..-..', row) is None
                   and row.strip(' ') != 'NCAA']
        mask = [row for row in content 
                if row.startswith('2 0 2 1  N B A  D R A F T  G U I D E')
                or row.strip().isdigit()]
        content = [row for row in content if row not in mask]
        output_dict[cat] = ''.join(content[1:])

    return output_dict

# %%
clean_scouting_report(sr_dict['Sandro Mamukelashvili'])
# Out:
#  'Summary': 'May be the most bizarre player in the 2021 NBA Draft. Can’t emphasize enough how weird his game is. He’s going to be a very situational player. Needs to find a team that will be willing to take advantage of his ability to grab and go and lead the break, as well as his dexterity and fluidity with the ball in his hands. He also needs to find the right home defensively with a scheme that can insulate him. There are limited parameters where he’s going to be truly successful, but if the right team can unlock him and he gets the jumper figured out in terms of consistency, he could be a legitimately interesting third big man. Mamukelashvili can take advantage of a lot of different mismatches in the NBA. There’s a real amount of Kelly Olynyk with increased passing ability here due Mamukelashvili’s mobility. Ultimately though, the thing that will glue it all together is the jumper. He’s really close to being a guarantee guy for me despite the defensive issues because the upside is that useful on offense in the right situation. But he won’t be for everybody. '}

# %%
for key in sr_dict:
    sr_dict[key] = clean_scouting_report(sr_dict[key])

# %% [markdown]
# ## Assemble Data

# %% [markdown]
# ### Add Scouting Report

# %%
cats = ['Strengths', 'Weaknesses', 'Summary']
for cat in cats:
    big_board[cat] = big_board['PLAYER'].apply(lambda x: sr_dict[x][cat])
    
big_board = big_board.rename(columns={cat: cat.upper() for cat in cats})

# %% [markdown]
# ### Add Tier Description

# %%
big_board['TIER_DESCRIP'] = big_board['TIER'].apply(lambda x: tier_dict[f'Tier {x}'])

# %%
big_board.head()
# Out:
#   RANK            PLAYER      SCHOOL/TEAM  POS AGE   HT WING TIER  \
# 0    1   Cade Cunningham   Oklahoma State  G/W  19  6-8  7-1    1
# 1    2       Jalen Suggs          Gonzaga    G  20  6-4  6-6    2
# 2    3       Evan Mobley              USC    C  20  7-0  7-4    2
# 3    4       Jalen Green  G League Ignite    G  19  6-5  6-8    2
# 4    5  Jonathan Kuminga  G League Ignite    W  18  6-8  7-0    3
#
#                                            STRENGTHS  \
# 0  Cunningham has elite-level size as a lead crea...
# 1  Ideal size for a lead guard creator. Powerful ...
# 2  Terrific physical tools for the modern center ...
# 3  The most explosive athlete of this class. All ...
# 4  Ideal measurements for a big wing initiator ty...
#
#                                           WEAKNESSES  \
# 0  Cunningham is a good athlete, but not a great ...
# 1  Sometimes gets a bit wild. Turned it over thre...
# 2  Mobley is still very skinny, and his frame isn...
# 3  Two big questions. First comes on defense. Gre...
# 4  Kuminga is not a good defender right now. It’s...
#
#                                              SUMMARY            TIER_DESCRIP
# 0  Cunningham is one of the more complete prospec...        Superstar Upside
# 1  Few things are more valuable in the NBA than a...         All-Star Upside
# 2  Mobley has all the tools to be an All-NBA big ...         All-Star Upside
# 3  I was really impressed with what I saw from Gr...         All-Star Upside
# 4  I expected Kuminga to be the best of the group...  High Leverage Starters

# %% [markdown]
# ## Save output

# %%
big_board.to_csv('../processed_csv/2021.csv', index=False)
