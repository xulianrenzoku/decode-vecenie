# %%
import os
import re
import pandas as pd
import numpy as np
from tika import parser

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_rows', 100)

# %%
os.listdir('../processed_pdf')
# Out:
# ['2020.pdf', '2021.pdf', '2023.pdf', '2022.pdf']

# %% [markdown]
# ## Read Raw Data

# %%
raw = parser.from_file('../processed_pdf/2023.pdf')
# print(raw['content'])

# %%
raw = raw['content'].split('\n')

# %%
print(len(raw))
raw = [row for row in raw if row != '']
print(len(raw))
# Out:
# 9401
# 7066

# %% [markdown]
# ## Get Tier

# %%
def get_tier(raw):
    tier_dict = {}
    tier_flag = 0
    
    for i, row in enumerate(raw, 0):
        if row.startswith('Tier'):
            key, value = row.split(': ')
            tier_dict[key] = value
            tier_flag = 1
        else:
            if tier_flag == 1:
                return tier_dict, raw[i:]

# %%
tier_dict, raw = get_tier(raw)

# %%
tier_dict
# Out:
# {'Tier Vic': 'Victor Wembanyama',
#  'Tier 1': 'Projectable All-NBA Upside',
#  'Tier 2': 'Projectable All-Star Upside',
#  'Tier 3': 'High-Leverage Starters',
#  'Tier 4': 'Starter/All-Star Tool Swings',
#  'Tier 6': 'Second-Round Guarantee Swings',
#  'Tier 7': 'Priority Two-Ways',
#  'Tier 8': 'Two-Ways, Stashes, Exhibit 10s',
#  'Tier 5': 'Rotation Players and Upside Swings'}

# %% [markdown]
# ## Get Big Board

# %%
def get_raw_big_board(raw):
    raw_bb_dict = {}
    bb_flag = 0
    bb_data = []
    
    for i, row in enumerate(raw, 0):
        if row.startswith('RANK'):
            raw_bb_dict['columns'] = row
            bb_flag = 1
        else:
            if bb_flag == 1:
                if row.split(' ')[0] != '100':
                    bb_data.append(row)
                else:
                    bb_data.append(row)
                    raw_bb_dict['data'] = bb_data
                    return raw_bb_dict, raw[i+1:]

# %%
raw_bb_dict, raw = get_raw_big_board(raw)

# %%
def build_big_board(raw_bb_dict):
    columns = [col.replace('.', '').replace(',', '')
               for col in raw_bb_dict['columns'].split(' ')]
    
    data = [row for row in raw_bb_dict['data']
            if len(row.split(' ')[0]) <= 3]
    
    processed_data = []
    for row in data:
        front, back = row.split(', ')
        row_adj = [front.split(' ')[0]] + [' '.join(front.split(' ')[1:])] + \
                  [' '.join(back.split(' ')[:-5])] + back.split(' ')[-5:]
        processed_data.append(row_adj)
    
    return pd.DataFrame(processed_data, columns=columns)

# %%
big_board = build_big_board(raw_bb_dict)
big_board
# Out:
#    RANK                   PLAYER           SCHOOL/TEAM  POS AGE    HT  WING  \
# 0     1        Victor Wembanyama      Metropolitans 92    C  19   7-4   8-0
# 1     2          Scoot Henderson       G League Ignite    G  19   6-2   N/A
# 2     3             Cam Whitmore             Villanova    W  18   6-6   6-9
# 3     4           Brandon Miller               Alabama  W/F  20   6-8   N/A
# 4     5            Amen Thompson        Overtime Elite    G  20   6-6   7-0
# 5     6            Jarace Walker               Houston    F  19   6-7   7-3
# 6     7         Taylor Hendricks                   UCF  W/F  19   6-8   7-1
# 7     8            Anthony Black              Arkansas  G/W  19   6-6   6-8
# 8     9           Ausar Thompson        Overtime Elite    W  20   6-6   7-0
# 9    10         Dereck Lively II                  Duke    C  19   7-1   N/A
# 10    4
# 11    4
# 12    4
# 13    4
# 14    4
# 15    4
# 16    5
# 17    5
# 18    5
# 19    5
# 20    5
# 21    5
# 22    5
# 23    5
# 24    5
# 25    5
# 26    5
# 27    5
# 28    5
# 29    5
# 30    5
# 31    5
# 32    5
# 33    5
# 34    5
# 35    5
# 36    6
# 37    6
# 38    6
# 39    6
# 40    6
# 41    6
# 42    7
# 43    7
# 44    7
# 45    7
# 46    7
# 47    7
# 48    7
# 49    7
# 50    7
# 51    7
# 52    7
# 53    8
# 54    8
# 55    8
# 56    8
# 57    8
# 58    8
# 59    8
# 60    8
# 61    8
# 62    8
# 63    8
# 64    8
# 65    8
# 66    8
# 67    8
# 68    8
# 69    8
# 70    8
# 71    8
# 72    8
# 73    8
# 74    8
# 75    8
# 76    8
# 77    8
# 78    8
# 79    8
# 80    8
# 81    8
# 82    8
# 83    8
# 84    8
# 85    8
# 86    8
# 87    8
# 88    8
# 89    8
# 90    8
# 91    8
# 92    8
# 93    8
# 94    8
# 95    8
# 96    8
# 97    8
# 98    8
# 99    8

# %%
big_board['PLAYER'] = big_board['PLAYER'].apply(lambda x: 'Gregory “G.G.” Jackson' if x == 'G.G. Jackson' else x)\
                                         .apply(lambda x: "Sir’Jabari Rice" if x == "Sir'Jabari Rice" else x)\
                                         .apply(lambda x: 'Tosan Evbuomwan' if x == 'Tosan Evbuomwam' else x)

# %% [markdown]
# ## Get Scouting Report

# %% [markdown]
# ### Build Raw Dict

# %%
raw = [row.replace('\t', ' ') for row in raw]

# %%
def identify_scouting_report(raw, big_board):
    sr_dict = {}
    idx_breaks = []
    players_identified = []

    for player in big_board.PLAYER.values:
        for i, row in enumerate(raw, 0):
            if row.endswith(player):
                idx_breaks.append(i)
                players_identified.append(player)
                break
    
    idx_breaks = idx_breaks + [len(raw)]

    for i, player in enumerate(players_identified, 0):
        start = idx_breaks[i]
        end = idx_breaks[i+1]
        sr_dict[player] = [row.lstrip(' ') for row in raw[start:end]]
        
    # report
    print(f'# of players identified: {len(players_identified)}')
    
    return sr_dict

# %%
sr_dict = identify_scouting_report(raw, big_board)
# Out:
# # of players identified: 75

# %%
def check_categories(sc):
    n_err = 0
    for cat in ['BACKGROUND', 'STRENGTHS', 'WEAKNESSES', 'SUMMARY']:
        if cat not in sc:
            print(cat)
            n_err += 1
    return n_err

# %%
for player in sr_dict.keys():
    if check_categories(sr_dict[player]) >= 1:
        print(player)

# %% [markdown]
# ### Clean Scouting Report

# %%
def clean_scouting_report(sr):
    school = sr[1].split(' | ')[1]
    idx_breaks = []
    
    cats = ['BACKGROUND', 'STRENGTHS', 'WEAKNESSES', 'SUMMARY']
    
    for cat in cats:
        for i, row in enumerate(sr, 0):
            if row == cat:
                idx_breaks.append(i)
                break
                
    idx_breaks = idx_breaks + [len(sr)]
    
    output_dict = {}
    
    for i, cat in enumerate(cats, 0):
        start = idx_breaks[i]
        end = idx_breaks[i+1]
        content = [row.strip('-') for row in sr[start:end] 
                   if row.endswith(' ') or row.endswith('.') or row.endswith('-')]
        content = [row for row in content
                   if re.search(f'^20..-.. {school}', row) is None]
        output_dict[cat] = ''.join(content)

    return output_dict

# %%
clean_scouting_report(sr_dict['Andre Jackson'])
# Out:
tempo and make plays for his teammates. So, where does that leave us? At the end of the day, I’m just willing to bet on Jackson. I think he and a smart coaching staff figure out how to use his elite basketball IQ and athleticism to their advantage. It’s also heartening that a lot of the best teams in the league have players like this on their roster and utilize real offensive movement to make them effective. Think about the Warriors with Gary Payton II or Denver with Bruce Brown. Brown’s level of impact is probably unattainable unless Jackson improves drastically in terms of his shot, but Payton is doable. Jackson is a similarly elite athlete to Payton – not a small feat – and is similarly a genius- level processor of the game at speed. Not every team is going to be interested in Jackson. It’s going to take someone creative. But if you’re willing to put in the work, Jackson can be an impactful non-shooter.  '}

# %%
for key in sr_dict:
    sr_dict[key] = clean_scouting_report(sr_dict[key])

# %% [markdown]
# ## Assemble Data

# %%
big_board['is_sr'] = big_board['PLAYER'].apply(lambda x: 1 if x in sr_dict.keys() else 0)
big_board = big_board[big_board['is_sr'] == 1]
big_board.shape
# Out:
# (75, 9)

# %% [markdown]
# ### Add Scouting Report

# %%
cats = ['BACKGROUND', 'STRENGTHS', 'WEAKNESSES', 'SUMMARY']
for cat in cats:
    big_board[cat] = big_board['PLAYER'].apply(lambda x: sr_dict[x][cat])
    
big_board = big_board.drop('is_sr', axis=1)

# %% [markdown]
# ### Add Tier Description

# %%
big_board['TIER_DESCRIP'] = big_board['TIER'].apply(lambda x: tier_dict[f'Tier {x}'])

# %%
big_board.head()
# Out:
#   RANK             PLAYER       SCHOOL/TEAM  POS AGE   HT WING TIER  \
# 0    1  Victor Wembanyama  Metropolitans 92    C  19  7-4  8-0  Vic
# 1    2    Scoot Henderson   G League Ignite    G  19  6-2  N/A    1
# 2    3       Cam Whitmore         Villanova    W  18  6-6  6-9    2
# 3    4     Brandon Miller           Alabama  W/F  20  6-8  N/A    2
# 4    5      Amen Thompson    Overtime Elite    G  20  6-6  7-0    2
#
#                                           BACKGROUND  \
# 0  Wembanyama has long been considered one of the...
# 1  Real name is Sterling. Went by Scoota at one p...
# 2  Parents are Beth and Myron. Father was in the ...
# 3  Parents are Darrell and Yolanda. Darrell was a...
# 4  Twin brother of fellow 2023 prospect Ausar Tho...
#
#                                            STRENGTHS  \
# 0  Wembanyama has elite length for a center. He s...
# 1  Elite athlete for the lead guard position. He’...
# 2  Elite intersection of size, frame, athleticism...
# 3  Great size for a floor-spacing wing at 6-foot-...
# 4  Amen is the elite of the elite athletically. W...
#
#                                           WEAKNESSES  \
# 0  There are a few, but not many. Wembanyama has ...
# 1  The real one is that Henderson is a bit small ...
# 2  Whitmore has all the physical tools to be an N...
# 3  The critical concern here is strength in Mille...
# 4  The critical question here is shooting. Amen h...
#
#                                              SUMMARY  \
# 0  Wembanyama is the highest-upside prospect to e...
# 1  In many other drafts, Henderson would be the N...
# 2  Whitmore is a pure upside play. If you buy int...
# 3  It’s hard to look past Miller’s combination of...
# 4  Thompson has all the physical tools you could ...
#
#                   TIER_DESCRIP
# 0            Victor Wembanyama
# 1   Projectable All-NBA Upside
# 2  Projectable All-Star Upside
# 3  Projectable All-Star Upside
# 4  Projectable All-Star Upside

# %% [markdown]
# ## Save output

# %%
big_board.to_csv('../processed_csv/2023.csv', index=False)
